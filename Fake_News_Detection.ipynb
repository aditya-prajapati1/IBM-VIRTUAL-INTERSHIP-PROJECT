# %%
import pandas as pd
import numpy as np

# %%
true = pd.read_csv('True.csv')

# %%
fake = pd.read_csv('Fake.csv')

# %%
true.head()
# Out:
#                                                title  \
# 0  As U.S. budget fight looms, Republicans flip t...
# 1  U.S. military to accept transgender recruits o...
# 2  Senior U.S. Republican senator: 'Let Mr. Muell...
# 3  FBI Russia probe helped by Australian diplomat...
# 4  Trump wants Postal Service to charge 'much mor...
#
#                                                 text       subject  \
# 0  WASHINGTON (Reuters) - The head of a conservat...  politicsNews
# 1  WASHINGTON (Reuters) - Transgender people will...  politicsNews
# 2  WASHINGTON (Reuters) - The special counsel inv...  politicsNews
# 3  WASHINGTON (Reuters) - Trump campaign adviser ...  politicsNews
# 4  SEATTLE/WASHINGTON (Reuters) - President Donal...  politicsNews
#
#                  date
# 0  December 31, 2017
# 1  December 29, 2017
# 2  December 31, 2017
# 3  December 30, 2017
# 4  December 29, 2017

# %%
fake.head()
# Out:
#                                                title  \
# 0   Donald Trump Sends Out Embarrassing New Year’...
# 1   Drunk Bragging Trump Staffer Started Russian ...
# 2   Sheriff David Clarke Becomes An Internet Joke...
# 3   Trump Is So Obsessed He Even Has Obama’s Name...
# 4   Pope Francis Just Called Out Donald Trump Dur...
#
#                                                 text subject  \
# 0  Donald Trump just couldn t wish all Americans ...    News
# 1  House Intelligence Committee Chairman Devin Nu...    News
# 2  On Friday, it was revealed that former Milwauk...    News
# 3  On Christmas day, Donald Trump announced that ...    News
# 4  Pope Francis used his annual Christmas Day mes...    News
#
#                 date
# 0  December 31, 2017
# 1  December 31, 2017
# 2  December 30, 2017
# 3  December 29, 2017
# 4  December 25, 2017

# %%
true['label']=1

# %%
fake['label'] = 0

# %%
true.head()
# Out:
#                                                title  \
# 0  As U.S. budget fight looms, Republicans flip t...
# 1  U.S. military to accept transgender recruits o...
# 2  Senior U.S. Republican senator: 'Let Mr. Muell...
# 3  FBI Russia probe helped by Australian diplomat...
# 4  Trump wants Postal Service to charge 'much mor...
#
#                                                 text       subject  \
# 0  WASHINGTON (Reuters) - The head of a conservat...  politicsNews
# 1  WASHINGTON (Reuters) - Transgender people will...  politicsNews
# 2  WASHINGTON (Reuters) - The special counsel inv...  politicsNews
# 3  WASHINGTON (Reuters) - Trump campaign adviser ...  politicsNews
# 4  SEATTLE/WASHINGTON (Reuters) - President Donal...  politicsNews
#
#                  date  label
# 0  December 31, 2017       1
# 1  December 29, 2017       1
# 2  December 31, 2017       1
# 3  December 30, 2017       1
# 4  December 29, 2017       1

# %%
fake.head()
# Out:
#                                                title  \
# 0   Donald Trump Sends Out Embarrassing New Year’...
# 1   Drunk Bragging Trump Staffer Started Russian ...
# 2   Sheriff David Clarke Becomes An Internet Joke...
# 3   Trump Is So Obsessed He Even Has Obama’s Name...
# 4   Pope Francis Just Called Out Donald Trump Dur...
#
#                                                 text subject  \
# 0  Donald Trump just couldn t wish all Americans ...    News
# 1  House Intelligence Committee Chairman Devin Nu...    News
# 2  On Friday, it was revealed that former Milwauk...    News
# 3  On Christmas day, Donald Trump announced that ...    News
# 4  Pope Francis used his annual Christmas Day mes...    News
#
#                 date  label
# 0  December 31, 2017      0
# 1  December 31, 2017      0
# 2  December 30, 2017      0
# 3  December 29, 2017      0
# 4  December 25, 2017      0

# %%
news = pd.concat([fake,true],axis=0)

# %%
news.head()
# Out:
#                                                title  \
# 0   Donald Trump Sends Out Embarrassing New Year’...
# 1   Drunk Bragging Trump Staffer Started Russian ...
# 2   Sheriff David Clarke Becomes An Internet Joke...
# 3   Trump Is So Obsessed He Even Has Obama’s Name...
# 4   Pope Francis Just Called Out Donald Trump Dur...
#
#                                                 text subject  \
# 0  Donald Trump just couldn t wish all Americans ...    News
# 1  House Intelligence Committee Chairman Devin Nu...    News
# 2  On Friday, it was revealed that former Milwauk...    News
# 3  On Christmas day, Donald Trump announced that ...    News
# 4  Pope Francis used his annual Christmas Day mes...    News
#
#                 date  label
# 0  December 31, 2017      0
# 1  December 31, 2017      0
# 2  December 30, 2017      0
# 3  December 29, 2017      0
# 4  December 25, 2017      0

# %%
news.tail()
# Out:
#                                                    title  \
# 21412  'Fully committed' NATO backs new U.S. approach...
# 21413  LexisNexis withdrew two products from Chinese ...
# 21414  Minsk cultural hub becomes haven from authorities
# 21415  Vatican upbeat on possibility of Pope Francis ...
# 21416  Indonesia to buy $1.14 billion worth of Russia...
#
#                                                     text    subject  \
# 21412  BRUSSELS (Reuters) - NATO allies on Tuesday we...  worldnews
# 21413  LONDON (Reuters) - LexisNexis, a provider of l...  worldnews
# 21414  MINSK (Reuters) - In the shadow of disused Sov...  worldnews
# 21415  MOSCOW (Reuters) - Vatican Secretary of State ...  worldnews
# 21416  JAKARTA (Reuters) - Indonesia will buy 11 Sukh...  worldnews
#
#                    date  label
# 21412  August 22, 2017       1
# 21413  August 22, 2017       1
# 21414  August 22, 2017       1
# 21415  August 22, 2017       1
# 21416  August 22, 2017       1

# %%
news.isnull().sum()
# Out:
# title      0
# text       0
# subject    0
# date       0
# label      0
# dtype: int64

# %%
news = news.drop(['title','subject','date'],axis=1)

# %%
news.head()
# Out:
#                                                 text  label
# 0  Donald Trump just couldn t wish all Americans ...      0
# 1  House Intelligence Committee Chairman Devin Nu...      0
# 2  On Friday, it was revealed that former Milwauk...      0
# 3  On Christmas day, Donald Trump announced that ...      0
# 4  Pope Francis used his annual Christmas Day mes...      0

# %%
news = news.sample(frac=1)

# %%
news.head()
# Out:
#                                                     text  label
# 15267  BRUSSELS (Reuters) - U.S. Defense Secretary Ji...      1
# 15714  BRUSSELS (Reuters) - Belgian authorities have ...      1
# 20367  After 9 Months Of Hard-Core Islam Muslim  Cloc...      0
# 21134  It turns out we re not as divided as people ma...      0
# 10696  MSNBC host Thomas Roberts on Sunday was specul...      0

# %%
news.reset_index(inplace=True)

# %%
news.head()
# Out:
#    index                                               text  label
# 0  15267  BRUSSELS (Reuters) - U.S. Defense Secretary Ji...      1
# 1  15714  BRUSSELS (Reuters) - Belgian authorities have ...      1
# 2  20367  After 9 Months Of Hard-Core Islam Muslim  Cloc...      0
# 3  21134  It turns out we re not as divided as people ma...      0
# 4  10696  MSNBC host Thomas Roberts on Sunday was specul...      0

# %%
news.drop(['index'],axis=1, inplace = True)

# %%
news.head()
# Out:
#                                                 text  label
# 0  BRUSSELS (Reuters) - U.S. Defense Secretary Ji...      1
# 1  BRUSSELS (Reuters) - Belgian authorities have ...      1
# 2  After 9 Months Of Hard-Core Islam Muslim  Cloc...      0
# 3  It turns out we re not as divided as people ma...      0
# 4  MSNBC host Thomas Roberts on Sunday was specul...      0

# %%
import re

# %%
def wordopt(text):
    text = text.lower()

    text = re.sub(r'https?://\S+|www\.\S+','',text)

    text = re.sub(r'[^\w\s]','',text)

    text = re.sub(r'\d','',text)

    text = re.sub(r'\n','',text)

    return text

# %%
news['text'] = news['text'].apply(wordopt)

# %%
news['text']
# Out:
# 0        brussels reuters  us defense secretary jim mat...
# 1        brussels reuters  belgian authorities have rec...
# 2        after  months of hardcore islam muslim  clock ...
# 3        it turns out we re not as divided as people ma...
# 4        msnbc host thomas roberts on sunday was specul...
#                                ...
# 44893    following the horrific tragedy in dallas texas...
# 44894    tokyo reuters  japan s coast guard on thursday...
# 44895    washington reuters  the us senate intelligence...
# 44896    bill clinton has been accused of multiple rape...
# 44897    washington reuters  the united states has made...
# Name: text, Length: 44898, dtype: object

# %%
x = news['text']
y = news['label']

# %%
x
# Out:
# 0        brussels reuters  us defense secretary jim mat...
# 1        brussels reuters  belgian authorities have rec...
# 2        after  months of hardcore islam muslim  clock ...
# 3        it turns out we re not as divided as people ma...
# 4        msnbc host thomas roberts on sunday was specul...
#                                ...
# 44893    following the horrific tragedy in dallas texas...
# 44894    tokyo reuters  japan s coast guard on thursday...
# 44895    washington reuters  the us senate intelligence...
# 44896    bill clinton has been accused of multiple rape...
# 44897    washington reuters  the united states has made...
# Name: text, Length: 44898, dtype: object

# %%
y
# Out:
# 0        1
# 1        1
# 2        0
# 3        0
# 4        0
#         ..
# 44893    0
# 44894    1
# 44895    1
# 44896    0
# 44897    1
# Name: label, Length: 44898, dtype: int64

# %%
from sklearn.model_selection import train_test_split

# %%
x_train, x_test, y_train, y_test = train_test_split(x,y,test_size=0.3)

# %%
x_train.shape
# Out:
# (31428,)

# %%
x_test.shape
# Out:
# (13470,)

# %%
from sklearn.feature_extraction.text import TfidfVectorizer

# %%
vectorization = TfidfVectorizer()

# %%
xv_train = vectorization.fit_transform(x_train)

# %%
xv_test = vectorization.transform(x_test)

# %%
xv_train
# Out:
# <Compressed Sparse Row sparse matrix of dtype 'float64'
# 	with 6472706 stored elements and shape (31428, 175041)>

# %%
xv_test
# Out:
# <Compressed Sparse Row sparse matrix of dtype 'float64'
# 	with 2708829 stored elements and shape (13470, 175041)>

# %%
from sklearn.linear_model import LogisticRegression

# %%
LR = LogisticRegression()

# %%
LR.fit(xv_train, y_train)
# Out:
# LogisticRegression()

# %%
pred_lr = LR.predict(xv_test)

# %%
LR.score(xv_test, y_test)
# Out:
# 0.9881217520415738

# %%
from sklearn.metrics import classification_report, accuracy_score, confusion_matrix

# %%
print(classification_report(y_test, pred_lr))
print("Accuracy:", accuracy_score(y_test, pred_lr))
print(confusion_matrix(y_test, pred_lr))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.99      0.99      0.99      7096
#            1       0.98      0.99      0.99      6374
#
#     accuracy                           0.99     13470
#    macro avg       0.99      0.99      0.99     13470
# weighted avg       0.99      0.99      0.99     13470
#
# Accuracy: 0.9881217520415738
# [[6992  104]
#  [  56 6318]]

# %%
from sklearn.tree import DecisionTreeClassifier

# %%
DTC = DecisionTreeClassifier()

# %%
DTC.fit(xv_train, y_train)
# Out:
# DecisionTreeClassifier()

# %%
pred_dtc = DTC.predict(xv_test)

# %%
DTC.score(xv_test, y_test)
# Out:
# 0.9962138084632517

# %%
print(classification_report(y_test, pred_dtc))
# Out:
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00      7096
#            1       1.00      1.00      1.00      6374
#
#     accuracy                           1.00     13470
#    macro avg       1.00      1.00      1.00     13470
# weighted avg       1.00      1.00      1.00     13470

# %%
from sklearn.ensemble import RandomForestClassifier

# %%
rfc = RandomForestClassifier()

# %%
rfc.fit(xv_train, y_train)
# Out:
# RandomForestClassifier()

# %%
predict_rfc = rfc.predict(xv_test)

# %%
rfc.score(xv_test, y_test)
# Out:
# 0.9862657757980697

# %%
print(classification_report(y_test, predict_rfc))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.99      0.98      0.99      7096
#            1       0.98      0.99      0.99      6374
#
#     accuracy                           0.99     13470
#    macro avg       0.99      0.99      0.99     13470
# weighted avg       0.99      0.99      0.99     13470

# %%
from sklearn.ensemble import GradientBoostingClassifier

# %%
gbc = GradientBoostingClassifier()

# %%
gbc.fit(xv_train, y_train)
# Out:
# GradientBoostingClassifier()

# %%
pred_gbc = gbc.predict(xv_test)

# %%
gbc.score(xv_test, y_test)
# Out:
# 0.9953229398663697

# %%
print(classification_report(y_test, pred_gbc))
# Out:
#               precision    recall  f1-score   support
#
#            0       1.00      0.99      1.00      7096
#            1       0.99      1.00      1.00      6374
#
#     accuracy                           1.00     13470
#    macro avg       1.00      1.00      1.00     13470
# weighted avg       1.00      1.00      1.00     13470

# %% [markdown]
# ## Quick Start:

# %%
import re
import joblib
import pandas as pd

# Same text-cleaning function used during training
def wordopt(text):
    text = text.lower()
    text = re.sub(r'https?://\S+|www\.\S+', '', text)
    text = re.sub(r'[^\w\s]', '', text)
    text = re.sub(r'\d', '', text)
    text = re.sub(r'\n', '', text)
    return text

def output_label(n):
    if n == 0:
        return "It is a Fake News"
    elif n == 1:
        return "It is a Genuine News"

# Load the saved vectorizer and models from disk
vectorization = joblib.load('vectorizer.jb')
LR = joblib.load('model_lr.jb')
DTC = joblib.load('model_dtc.jb')
gbc = joblib.load('model_gbc.jb')
rfc = joblib.load('model_rfc.jb')

print("Loaded saved vectorizer and models. Ready to predict.")
# Out:
# Loaded saved vectorizer and models. Ready to predict.

# %%
def manual_testing(news):
    testing_news = {"text": [news]}
    new_def_test = pd.DataFrame(testing_news)

    # Apply the same cleaning used during training
    new_def_test["text"] = new_def_test["text"].apply(wordopt)

    # Transform using the SAME vectorizer used for training
    new_xv_test = vectorization.transform(new_def_test["text"])

    pred_lr = LR.predict(new_xv_test)
    pred_dt = DTC.predict(new_xv_test)
    pred_gbc = gbc.predict(new_xv_test)
    pred_rfc = rfc.predict(new_xv_test)

    return (
        "\n\nLR Prediction: {}"
        "\nDT Prediction: {}"
        "\nGBC Prediction: {}"
        "\nRFC Prediction: {}"
    ).format(
        output_label(pred_lr[0]),
        output_label(pred_dt[0]),
        output_label(pred_gbc[0]),
        output_label(pred_rfc[0])
    )

# %%
news_article = str(input())
# Out:
#  President Donald Trump announced yesterday that he plans to formally recognize Jerusalem as the capital of Israel. While this is left most pundits perplexed, the reasoning is clear. Trump wants to divert attention from Robert Mueller s investigation. It is no coincidence that the day after the news broke that Deutsche Bank has received subpoenas for information on the Trump family s assets, that this Jerusalem decision was announced. What could be a bigger news story than getting this information? A blow up in the Middle East.Look at the reaction world leaders have had to this announcement. American allies throughout the Middle East and Europe have asked Trump not to do this and have stressed how dangerous a statement this is. US News and World Report put this out today: The mere consideration of Trump changing the status quo sparked a renewed U.S. security warning on Tuesday. America s consulate in Jerusalem ordered U.S. personnel and their families to avoid visiting Jerusalem s Ol
# ...

# %%
print(manual_testing(news_article))
# Out:
# LR Prediction: It is a Fake News
# DT Prediction: It is a Fake News
# GBC Prediction: It is a Fake News
# RFC Prediction: It is a Fake News
